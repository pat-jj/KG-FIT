# %%
import numpy as np
from sklearn.cluster import AgglomerativeClustering
from openai import OpenAI
from typing import List
from sklearn.metrics import silhouette_score
from tqdm import tqdm
import argparse
import json
import os
import random
import logging
from concurrent.futures import ThreadPoolExecutor, as_completed
import concurrent.futures
import pickle

# %%
def construct_args():
    parser = argparse.ArgumentParser(description='Cluster entities using hierarchical clustering and refine the clusters using LLM.')
    parser.add_argument('--output_dir', type=str, default="/data/pj20/lamake_data")
    parser.add_argument('--data_dir', type=str, default="/home/pj20/server-03/lamake/data")
    parser.add_argument('--dataset', type=str, default="FB15K-237", help='Path to the dataset file containing the list of entities to cluster.')
    parser.add_argument('--dimensions', type=int, default=1024, help='Dimensionality of the embeddings. Default: 1024.')
    parser.add_argument('--num_threads', type=int, default=10, help='Number of threads to use for multi-threaded processes. Default: 10.')
    parser.add_argument('--max_entities', type=int, default=100, help='Maximum number of entities to include in an LLM request. Default: 100.')
    
    args = parser.parse_args(args=[])
    args.log_dir = f"{args.output_dir}/{args.dataset}/logs"
    
    return args

# %%
args = construct_args()

# %%
from cluster import  read_entities, create_entity_info_emb_dict, generate_embeddings, build_hierarchy

# %%
import pickle

clustering_file = "/data/pj20/lamake_data/FB15K-237/clustering/clustering_0.52.pkl"
with open(clustering_file, "rb") as f:
    clustering = pickle.load(f)

# %%
entities = read_entities('/home/pj20/server-03/lamake/data/FB15K-237/entities.dict')
entity_info, entity_embeddings = create_entity_info_emb_dict(args, entities)
entities_text, original_descriptions = [], []
for entity in entities:
    entities_text.append(entity_info[entity]["text_label"])
    original_descriptions.append(entity_info[entity]["original_description"])
    
print("Start Generating Embeddings...")
embeddings, entity_info, entity_embeddings = generate_embeddings(args, entity_info=entity_info, entity_embeddings=entity_embeddings, dim=args.dimensions)
# Out:
# Start Generating Embeddings...
# Loading existing entity embeddings from /data/pj20/lamake_data/FB15K-237/entity_embeddings.json...
# Done.
# All entities have valid embeddings. Skipping embedding generation.
# Loading existing entity info from /data/pj20/lamake_data/FB15K-237/entity_info.json...
# Done.

# %%
clusters = {}
for i in range(clustering.n_clusters_):
    cluster_indices = np.where(clustering.labels_ == i)[0]
    cluster_entities = [entities_text[idx] for idx in cluster_indices]
    clusters[f"Cluster_{i+1}"] = cluster_entities

# %%
clusters_ = {int(i): entities for i, entities in enumerate(clusters.values())}

# %%
len(entities)
# Out:
# 14541

# %%
clustering.children_
# Out:
# array([[ 1422, 12516],
#        [ 1275,  4592],
#        [12324, 13070],
#        ...,
#        [29074, 29076],
#        [ 5241, 29077],
#        [29078, 29079]])

# %%
initial_hier = build_hierarchy(clustering.children_, len(entities), entity_labels=entities_text, clustering=clustering)

# %%
clusters_ = {int(i): entities for i, entities in enumerate(clusters.values())}
entity2clusterid = {}

for i, cluster in enumerate(clusters_.values()):
    for entity in cluster:
        entity2clusterid[entity] = i
        
clusterid2count = defaultdict(int)

# %%
entity2clusterid
# Out:
# {'comedy-drama': 0,
#  'romance film': 0,
#  'sketch comedy': 0,
#  'television comedy': 0,
#  'comedian': 0,
#  'romantic comedy': 0,
#  'black comedy': 0,
#  'comedy film': 0,
#  'Comedy': 0,
#  'comedy of manners': 0,
#  'stand-up comedy': 0,
#  'sex comedy': 0,
#  'screwball comedy film': 0,
#  'situation comedy': 0,
#  'Paddington': 1,
#  'Hammersmith': 1,
#  'Kensington': 1,
#  'Wandsworth': 1,
#  'Chiswick': 1,
#  'Hampstead': 1,
#  'Marylebone': 1,
#  'Ealing': 1,
#  'Kannada': 2,
#  'Mangalore': 2,
#  'Mysore': 2,
#  'Karnataka': 2,
#  'Metropolis Records': 3,
#  'Tooth & Nail Records': 3,
#  'Southern Lord Records': 3,
#  'Revelation Records': 3,
#  'Roadrunner Records': 3,
#  'Century Media Records': 3,
#  'Nuclear Blast': 3,
#  'Equal Vision Records': 3,
#  'The End Records': 3,
#  'Relapse Records': 3,
#  'Cleopatra Records': 3,
#  'Chrysalis Records': 3,
#  'Victory Records': 3,
#  'Frontiers Records': 3,
#  'Candlelight Records': 3,
#  'Napalm Records': 3,
#  'Metal Blade Records': 3,
#  'Season of Mist': 3,
#  'Earache Records': 3,
#  'Spinefarm Records': 3,
#  'Epitaph Records': 3,
#  'Nick Park': 4,
#  'Pete Docter': 4,
#  'Andrew Stanton': 4,
#  'John Lasseter': 4,
#  'Pixar': 4,
#  'John Conyers': 5,
#  'John Dingell, Jr.': 5,
#  'Donald M. Payne': 5,
#  'Charles B. Rangel': 5,
#  'Andy Dick': 6,
#  'Adam Carolla': 6,
#  'Howie Mandel': 6,
#  'Howard Stern': 6,
#  'Artie Lange': 6,
#  'This Must Be the Place': 7,
#  'This Is England': 7,
#  'Marc Anthony': 8,
#  'Ricky Martin': 8,
#  'Luis Miguel': 8,
#  'Enrique Iglesias': 8,
#  'Daddy Yankee': 8,
#  'Draco Rosa': 8,
#  'Alejandro Sanz': 8,
#  'Fukuoka Prefecture': 9,
#  'Chiba Prefecture': 9,
#  'Nagano Prefecture': 9,
#  'Okinawa Prefecture': 9,
#  'Saitama Prefecture': 9,
#  'Miyagi Prefecture': 9,
#  'Fukuoka': 9,
#  'Niigata Prefecture': 9,
#  'Kyushu': 9,
#  'Kagoshima Prefecture': 9,
#  'Kanagawa Prefecture': 9,
#  'Fukushima Prefecture': 9,
#  'Shizuoka Prefecture': 9,
#  'Ibaraki Prefecture': 9,
#  'Gifu Prefecture': 9,
#  'Kagoshima': 9,
#  'Shannen Doherty': 10,
#  'Darren Star': 10,
#  'Jason Priestley': 10,
#  'Aaron Spelling': 10,
#  'Tori Spelling': 10,
#  'Christopher Cerf': 11,
#  'Tony Geiss': 11,
#  'Super': 12,
#  'superhero': 12,
#  'superhero film': 12,
#  'Heroes': 12,
#  'Friday Night Lights': 13,
#  'Remember the Titans': 13,
#  'Any Given Sunday': 13,
#  'Midnight Cowboy': 14,
#  'Midnight in the Garden of Good and Evil': 14,
#  'Midnight Express': 14,
#  'Carl Foreman': 15,
#  'Charles Brackett': 15,
#  'Dore Schary': 15,
#  'Santa Fe': 16,
#  'New Mexico': 16,
#  'Las Cruces': 16,
#  'Sandoval County': 16,
#  'Santa Fe Province': 16,
#  'Santa Fe County': 16,
#  'Albuquerque': 16,
#  'Bernalillo County': 16,
#  'Bob Clark': 17,
#  'Clive A. Smith': 17,
#  'Jim Clark': 17,
#  'Carroll Clark': 17,
#  'Steven Curtis Chapman': 18,
#  'Amy Grant': 18,
#  'Yolanda Adams': 18,
#  'CeCe Winans': 18,
#  'BeBe Winans': 18,
#  'Michael W. Smith': 18,
#  'Dave Chappelle': 19,
#  'David Krumholtz': 19,
#  'David Zayas': 19,
#  'David Koechner': 19,
#  'David Spade': 19,
#  'David Paymer': 19,
#  'David Cross': 19,
#  'David Dhawan': 19,
#  'David Wain': 19,
#  'David Arquette': 19,
#  'Billy Idol': 20,
#  'Adam Ant': 20,
#  'Iggy Pop': 20,
#  'In the Bedroom': 21,
#  'Little Children': 21,
#  'The Squid and the Whale': 21,
#  'sales': 22,
#  'retail': 22,
#  'New York University Stern School of Business': 23,
#  'Stanford Graduate School of Business': 23,
#  'Medill School of Journalism': 23,
#  'MIT Sloan School of Management': 23,
#  'Columbia University Graduate School of Journalism': 23,
#  'Columbia Business School': 23,
#  'Harvard Business School': 23,
#  'Kellogg School of Management': 23,
#  'Guinea-Bissau': 24,
#  'Benin': 24,
#  'Nigeria': 24,
#  'Niger': 24,
#  'The Gambia': 24,
#  'Burkina Faso': 24,
#  'Mali': 24,
#  'Dakar': 24,
#  'Guinea': 24,
#  'Senegal': 24,
#  'Hershey Bears': 25,
#  'Bridgeport Sound Tigers': 25,
#  'Oklahoma City Barons': 25,
#  'Connecticut Whale': 25,
#  'Syracuse Crunch': 25,
#  'New Jersey Devils': 25,
#  'Springfield Falcons': 25,
#  'Norfolk Admirals': 25,
#  'Rockford IceHogs': 25,
#  'ECHL': 25,
#  'Albany Devils': 25,
#  'Milwaukee Admirals': 25,
#  'American Hockey League': 25,
#  'Manchester Monarchs': 25,
#  'Starsky & Hutch': 26,
#  'Tango & Cash': 26,
#  'Miami Vice': 26,
#  'Airplane!': 27,
#  'Flight': 27,
#  'Airport': 27,
#  'Sarnia': 28,
#  'Sault Ste. Marie': 28,
#  'Port Huron': 28,
#  'Thunder Bay': 28,
#  'Academy Award for Best Director': 29,
#  'Academy Award for Best Sound Editing': 29,
#  'Academy Award for Best Supporting Actor': 29,
#  'BAFTA Award for Best Actor in a Supporting Role': 29,
#  'BAFTA Award for Best Special Visual Effects': 29,
#  'BAFTA Award for Best Makeup and Hair': 29,
#  'Academy Award for Best Original Song': 29,
#  'Satellite Award for Best Animated or Mixed Media Feature': 29,
#  'Academy Award for Best Visual Effects': 29,
#  'Grammy Award for Best Song Written for a Motion Picture, Television or Other Visual Media': 29,
#  'BAFTA Award for Best Actress in a Supporting Role': 29,
#  'Academy Award for Best Original Score': 29,
#  'Academy Award for Best Costume Design': 29,
#  'British Academy Television Award for Best Actress': 29,
#  'Academy Award for Best Documentary, Short Subject': 29,
#  'BAFTA Award for Best Film Music': 29,
#  'Academy Award for Best Picture': 29,
#  'Academy Award for Best Animated Short Film': 29,
#  'BAFTA Award for Best Sound': 29,
#  'Academy Award for Best Cinematography': 29,
#  'BAFTA Award for Best Animated Film': 29,
#  'BAFTA Award for Best Actress in a Leading Role': 29,
#  'Academy Award for Best Story': 29,
#  'Golden Globe Award for Best Original Song': 29,
#  'AACTA Award for Best Cinematography': 29,
#  'Academy Award for Best Makeup and Hairstyling': 29,
#  'BIFA Award for Best Performance by an Actress in a British Independent Film': 29,
#  'Academy Award for Best Supporting Actress': 29,
#  'Academy Award for Best Animated Feature': 29,
#  'Academy Award for Best Live Action Short Film': 29,
#  'BAFTA Award for Best Actor in a Leading Role': 29,
#  'BAFTA Award for Best Film': 29,
#  'Golden Globe Award for Best Animated Feature Film': 29,
#  "Critics' Choice Movie Award for Best Animated Feature": 29,
#  'BIFA Award for Best Supporting Actress': 29,
#  'BIFA Award for Best British Independent Film': 29,
#  'Grammy Award for Best Compilation Soundtrack for Visual Media': 29,
#  'Golden Globe Award for Best Original Score': 29,
#  'Academy Award for Best Film Editing': 29,
#  'Academy Award for Best Production Design': 29,
#  'Academy Award for Best Documentary Feature': 29,
#  'Academy Award for Best Actor': 29,
#  'BAFTA Award for Best Editing': 29,
#  'Academy Award for Best Sound Mixing': 29,
#  'Grammy Award for Best Score Soundtrack for Visual Media': 29,
#  'Academy Award for Best Actress': 29,
#  'BAFTA Academy Fellowship Award': 29,
#  'Academy Award for Best Original Musical Score': 29,
#  'BAFTA Award for Best Direction': 29,
#  'Grammy Award for Best Music Film': 29,
#  'Grammy Award for Best Music Video': 29,
#  'γ-tocopherol': 30,
#  'alpha-tocopherol': 30,
#  '(E)-phytonadione': 30,
#  'Frederik Pohl': 31,
#  'John Varley': 31,
#  'Michael Swanwick': 31,
#  'Charles Stross': 31,
#  'Jack Vance': 31,
#  'David Brin': 31,
#  'Kim Stanley Robinson': 31,
#  'Roger Zelazny': 31,
#  'Joe Haldeman': 31,
#  'Poul Anderson': 31,
#  'Robert Silverberg': 31,
#  'Larry Niven': 31,
#  'Stephen Baxter': 31,
#  'Alastair Reynolds': 31,
#  'Robert A. Heinlein': 31,
#  'Greg Bear': 31,
#  'Vernor Vinge': 31,
#  'San Juan Jabloteh': 32,
#  'Portmore United F.C.': 32,
#  'psychedelic music': 33,
#  'psychedelic pop': 33,
#  'neo-psychedelia': 33,
#  'shoegazing': 33,
#  'psychedelic rock': 33,
#  'psychedelic soul': 33,
#  'surf music': 33,
#  'psychedelic folk': 33,
#  'dream pop': 33,
#  "Sullivan's Travels": 34,
#  'Preston Sturges': 34,
#  'It Happened One Night': 34,
#  'My Man Godfrey': 34,
#  'The Philadelphia Story': 34,
#  'An Ideal Husband': 35,
#  'Bel Ami': 35,
#  'Clive Barker': 36,
#  'Dead Ringers': 36,
#  'David Cronenberg': 36,
#  'Alsace': 37,
#  'Vaucluse': 37,
#  'Haute-Savoie': 37,
#  'Bas-Rhin': 37,
#  'Alpes-Maritimes': 37,
#  'Haut-Rhin': 37,
#  'A Beautiful Mind': 38,
#  'Confessions of a Dangerous Mind': 38,
#  'University of Sheffield': 39,
#  'University of Sydney': 39,
#  'Aberystwyth University': 39,
#  'University of St Andrews': 39,
#  'Australian National University': 39,
#  'University of New South Wales': 39,
#  'University of Lancaster': 39,
#  'Queensland University of Technology': 39,
#  'University of Dundee': 39,
#  'Victoria University of Wellington': 39,
#  'University of Sussex': 39,
#  'Loughborough University': 39,
#  'University of Queensland': 39,
#  'University of Wales': 39,
#  'University of the Witwatersrand': 39,
#  'Monash University': 39,
#  'University of Canterbury': 39,
#  'University of Adelaide': 39,
#  'Keele University': 39,
#  'University of Kent': 39,
#  'University of Otago': 39,
#  'University of Leeds': 39,
#  'Cardiff University': 39,
#  'University of Aberdeen': 39,
#  'Swansea University': 39,
#  'University of Oxford': 39,
#  'University of Strathclyde': 39,
#  'University of Bristol': 39,
#  'University of York': 39,
#  'Heriot-Watt University': 39,
#  'University of Reading': 39,
#  'Manchester Metropolitan University': 39,
#  "Queen's University": 39,
#  'University of Auckland': 39,
#  'University of Glasgow': 39,
#  'University of Edinburgh': 39,
#  'University of Manchester': 39,
#  'Stellenbosch University': 39,
#  "Queen's University Belfast": 39,
#  'University of Melbourne': 39,
#  'University College Dublin': 39,
#  'University College Cork': 39,
#  'University of East Anglia': 39,
#  'University of Birmingham': 39,
#  'University of Essex': 39,
#  'RMIT University': 39,
#  'University of Western Australia': 39,
#  'University of Leicester': 39,
#  'University of Liverpool': 39,
#  'Newcastle University': 39,
#  'St Andrews': 39,
#  'University of Nottingham': 39,
#  'University of Durham': 39,
#  'University of Cape Town': 39,
#  'Macquarie University': 39,
#  'Ed Weinberger': 40,
#  'Josh Weinstein': 40,
#  'Ron Weiner': 40,
#  'David Miner': 40,
#  'Lee Grant': 41,
#  'Lou Grant': 41,
#  'United States Senate': 42,
#  '89th United States Congress': 42,
#  '1st United States Congress': 42,
#  '91st United States Congress': 42,
#  '13th United States Congress': 42,
#  '94th United States Congress': 42,
#  '5th United States Congress': 42,
#  '113th United States Congress': 42,
#  '110th United States Congress': 42,
#  '97th United States Congress': 42,
#  'United States Congress': 42,
#  '104th United States Congress': 42,
#  '14th United States Congress': 42,
#  '99th United States Congress': 42,
#  '20th United States Congress': 42,
#  '92nd United States Congress': 42,
#  '3rd United States Congress': 42,
#  '102nd United States Congress': 42,
#  '101st United States Congress': 42,
#  '31st United States Congress': 42,
#  '111th United States Congress': 42,
#  '23rd United States Congress': 42,
#  'United States House of Representatives': 42,
#  '16th United States Congress': 42,
#  'House of Representatives': 42,
#  '15th United States Congress': 42,
#  '95th United States Congress': 42,
#  '112th United States Congress': 42,
#  '30th United States Congress': 42,
#  '9th United States Congress': 42,
#  '93rd United States Congress': 42,
#  '4th United States Congress': 42,
#  '32nd United States Congress': 42,
#  '11th United States Congress': 42,
#  '105th United States Congress': 42,
#  '103rd United States Congress': 42,
#  '27th United States Congress': 42,
#  '100th United States Congress': 42,
#  '107th United States Congress': 42,
#  '109th United States Congress': 42,
#  '108th United States Congress': 42,
#  '26th United States Congress': 42,
#  '6th United States Congress': 42,
#  '18th United States Congress': 42,
#  '88th United States Congress': 42,
#  '10th United States Congress': 42,
#  '90th United States Congress': 42,
#  '25th United States Congress': 42,
#  '28th United States Congress': 42,
#  '19th United States Congress': 42,
#  '2nd United States Congress': 42,
#  '98th United States Congress': 42,
#  '7th United States Congress': 42,
#  '96th United States Congress': 42,
#  '8th United States Congress': 42,
#  '106th United States Congress': 42,
#  '17th United States Congress': 42,
#  'Doubt': 43,
#  'John Patrick Shanley': 43,
#  'Irving Thalberg': 44,
#  'Richard D. Zanuck': 44,
#  'Michael Balcon': 44,
#  'Darryl F. Zanuck': 44,
#  'David O. Selznick': 44,
#  'Frederick M. Zollo': 44,
#  'Hal B. Wallis': 44,
#  'priest': 45,
#  'Priest': 45,
#  'preacher': 45,
#  'rabbi': 45,
#  'pastor': 45,
#  'clergy': 45,
#  'The Grudge': 46,
#  'The Gift': 46,
#  'The Ring': 46,
#  'The Illusionist': 47,
#  'Inception': 47,
#  'The Prestige': 47,
#  'Mark Ronson': 48,
#  'Robin Thicke': 48,
#  'Adam Levine': 48,
#  'Rob Thomas': 48,
#  'Bruno Mars': 48,
#  'Maroon 5': 48,
#  'David A. Stewart': 49,
#  'Rod Stewart': 49,
#  'Cat Stevens': 49,
#  'Stephen Stills': 49,
#  'Stewart Copeland': 49,
#  'University of Washington': 50,
#  'Washington State University': 50,
#  'Oregon State University': 50,
#  'Ohio State University': 50,
#  'Corvallis': 50,
#  'Holby City': 51,
#  'Scrubs': 51,
#  "Grey's Anatomy": 51,
#  'Chicago Hope': 51,
#  'Sharat Saxena': 52,
#  'Satish Shah': 52,
#  'Ashish Vidyarthi': 52,
#  'Satish Kaushik': 52,
#  'Ronnie Screwvala': 53,
#  'Scott Rudin': 53,
#  'Ryan Kavanaugh': 53,
#  'Crazy in Alabama': 54,
#  "Cookie's Fortune": 54,
#  'Ray Walston': 55,
#  'Ray Milland': 55,
#  'Raymond Massey': 55,
#  'University of Paris': 56,
#  'University of Bologna': 56,
#  'University of Padua': 56,
#  'Pontifical Gregorian University': 56,
#  'Padua': 56,
#  'Sapienza University of Rome': 56,
#  'University of Turin': 56,
#  'University of Pisa': 56,
#  'Sylvester Stallone': 57,
#  'Jean-Claude Van Damme': 57,
#  'Bruce Willis': 57,
#  'Dolph Lundgren': 57,
#  'Chuck Norris': 57,
#  'Steven Seagal': 57,
#  'S.C. Internacional': 58,
#  'S.C. Corinthians Paulista': 58,
#  'Santos F.C.': 58,
#  'Esporte Clube Bahia': 58,
#  'Sociedade Esportiva Palmeiras': 58,
#  'Cruzeiro E.C.': 58,
#  'Coritiba F.C.': 58,
#  'S.C. Braga': 58,
#  'Sport Club do Recife': 58,
#  'Stephen Rea': 59,
#  'Patrick McGoohan': 59,
#  'Stephen McHattie': 59,
#  'Isfahan': 60,
#  'Shiraz': 60,
#  'Tabriz': 60,
#  'Mashhad': 60,
#  'Eric Tsang': 61,
#  'Maggie Cheung': 61,
#  'Leslie Cheung': 61,
#  'Nicholas Tse': 61,
#  'Jesse Eisenberg': 62,
#  'Zach Galifianakis': 62,
#  'Billy Zane': 62,
#  'Steve Zahn': 62,
#  'Zach Braff': 62,
#  'Jason Schwartzman': 62,
#  'Zac Efron': 62,
#  'Blades of Glory': 63,
#  'Whip It': 63,
#  'Calabria': 64,
#  'Basilicata': 64,
#  'Province of Potenza': 64,
#  'Apulia': 64,
#  'Abruzzo': 64,
#  'Bari': 64,
#  'Herb Alpert': 65,
#  'Al Schmitt': 65,
#  'Long Island University': 66,
#  'Staten Island': 66,
#  'Long Island': 66,
#  'Buddy DeSylva': 67,
#  'George Gershwin': 67,
#  'Ira Gershwin': 67,
#  'Jimmy Buffett': 68,
#  'John Mellencamp': 68,
#  'Billy Joel': 68,
#  'Humberto Gatica': 69,
#  'Kuk Harrell': 69,
#  'Ellen Pompeo': 70,
#  'Justin Chambers': 70,
#  'Kate Walsh': 70,
#  'Chandra Wilson': 70,
#  'Patrick Dempsey': 70,
#  'James Pickens': 70,
#  'Sara Ramirez': 70,
#  'Eric Dane': 70,
#  'T. R. Knight': 70,
#  'Til Schweiger': 71,
#  'Liev Schreiber': 71,
#  'figure skating': 72,
#  'short track speed skating': 72,
#  'skateboarding': 72,
#  'cross-country skiing': 72,
#  'Nordic combined': 72,
#  'alpine skiing': 72,
#  'speed skating': 72,
#  'ski jumping': 72,
#  'snowboarding': 72,
#  'freestyle skiing': 72,
#  'SK Brann': 73,
#  'AC Horsens': 73,
#  'Aarhus Gymnastikforening': 73,
#  'Aalesunds FK': 73,
#  'Viking FK': 73,
#  'Vejle Boldklub': 73,
#  'Fredrikstad FK': 73,
#  'AIK Fotboll': 73,
#  'FC Midtjylland': 73,
#  'Esbjerg fB': 73,
#  'Molde FK': 73,
#  'Rosenborg BK': 73,
#  'Kalmar FF': 73,
#  'Lyngby Boldklub': 73,
#  'Odense Boldklub': 73,
#  'Helsingborgs IF': 73,
#  'Sandefjord Fotball': 73,
#  'IF Elfsborg': 73,
#  'Randers FC': 73,
#  'Silkeborg IF': 73,
#  'F.C. Copenhagen': 73,
#  'Viborg FF': 73,
#  '24: Redemption': 74,
#  '24': 74,
#  'Fear and Loathing in Las Vegas': 75,
#  'Naked Lunch': 75,
#  'The Unbearable Lightness of Being': 75,
#  'Ed Begley, Jr.': 76,
#  'Ed Lauter': 76,
#  'Eddie Albert': 76,
#  'Ed Asner': 76,
#  'Edward Herrmann': 76,
#  'E. G. Marshall': 76,
#  'Street Fighter II V': 77,
#  'Final Fantasy: The Spirits Within': 77,
#  'Final Fantasy VII: Advent Children': 77,
#  'Street Fighter II: The Animated Movie': 77,
#  'Joe Jackson': 78,
#  'George Michael': 78,
#  'Janet Jackson': 78,
#  'Michael Jackson': 78,
#  'Randy Jackson': 78,
#  'The Jackson 5': 78,
#  'La Toya Jackson': 78,
#  'Jermaine Jackson': 78,
#  'Fields Medal': 79,
#  'Benjamin Franklin Medal': 79,
#  'Royal Medal': 79,
#  'Perkin Medal': 79,
#  'AIA Gold Medal': 79,
#  'John Fritz Medal': 79,
#  'Edison Medal': 79,
#  'Copley Medal': 79,
#  'Franklin Medal': 79,
#  'Royal Gold Medal': 79,
#  'Gold Medal of the Royal Astronomical Society': 79,
#  'Unfaithful': 80,
#  'Fatal Attraction': 80,
#  'Dangerous Liaisons': 80,
#  'Cruel Intentions': 80,
#  'Portland Timbers': 81,
#  'Portland': 81,
#  'Portland Trail Blazers': 81,
#  'Portland Pirates': 81,
#  'University of Portland': 81,
#  'Portland State University': 81,
#  'Richard Rodgers': 82,
#  'Eric Rodwell': 82,
#  'Mary Astor': 83,
#  'Mary Pickford': 83,
#  'Frances Marion': 83,
#  'screenwriter': 84,
#  'playwright': 84,
#  'author': 84,
#  'writer': 84,
#  'poet': 84,
#  'meningitis': 85,
#  'sinusitis': 85,
#  'peritonitis': 85,
#  'common-law marriage': 86,
#  'civil union': 86,
#  'domestic partnership': 86,
#  'marriage': 86,
#  'Loving': 87,
#  'Love of Life': 87,
#  "McDonald's": 88,
#  'Fast Food Nation': 88,
#  'fast food': 88,
#  'Jaime Pressly': 89,
#  'Jessica Simpson': 89,
#  'Jennifer Love Hewitt': 89,
#  'Jessica Alba': 89,
#  'Jessica Biel': 89,
#  'Ashlee Simpson': 89,
#  'The Stand': 90,
#  'Stand by Me': 90,
#  'video': 91,
#  'VHS': 91,
#  "My Sister's Keeper": 92,
#  'The Kids Are All Right': 92,
#  'The Town': 93,
#  'Charlestown': 93,
#  'British Isles': 94,
#  'United Kingdom': 94,
#  'Scotland': 94,
#  'Ireland': 94,
#  'Northern Ireland': 94,
#  'England': 94,
#  'Great Britain': 94,
#  'Montreal Expos': 95,
#  'Montreal Canadiens': 95,
#  'Montreal Impact F.C.': 95,
#  'Montreal Alouettes': 95,
#  'Hamilton Bulldogs': 95,
#  'The Goonies': 96,
#  'The Pirate Movie': 96,
#  'Sardinia': 97,
#  'Sicily': 97,
#  'Corsica': 97,
#  'Messina': 97,
#  'Province of Palermo': 97,
#  'Catania': 97,
#  'Province of Cagliari': 97,
#  'Palermo': 97,
#  'road cycling': 98,
#  'cycling': 98,
#  'mountaineering': 98,
#  'mountain biking': 98,
#  'track cycling': 98,
#  'NOFX': 99,
#  'Dropkick Murphys': 99,
#  'Social Distortion': 99,
#  'Suicidal Tendencies': 99,
#  'The Offspring': 99,
#  'Camryn Manheim': 100,
#  'Rose McGowan': 100,
#  'The Glenn Miller Story': 101,
#  'Going My Way': 101,
#  'Annabeth Gish': 102,
#  'Gina McKee': 102,
#  'Gina Gershon': 102,
#  'Greta Scacchi': 102,
#  "Newell's Old Boys": 103,
#  'Club Atletico San Lorenzo de Almagro': 103,
#  'All Boys': 103,
#  'Boca Juniors': 103,
#  'A.A. Argentinos Juniors': 103,
#  'Adam Sandler': 104,
#  "That's My Boy": 104,
#  'Happy Madison': 104,
#  'Grown Ups': 104,
#  'Allen Covert': 104,
#  'Big Daddy': 104,
#  'Happy Gilmore': 104,
#  'Peru': 105,
#  'Ecuador': 105,
#  'Paraguay': 105,
#  'Chile': 105,
#  'Colombia': 105,
#  'Bolivia': 105,
#  'Quito': 105,
#  'August': 106,
#  'February': 106,
#  'April': 106,
#  'September': 106,
#  'May': 106,
#  'January': 106,
#  'December': 106,
#  'March': 106,
#  'October': 106,
#  'November': 106,
#  'June': 106,
#  'July': 106,
#  'Kathmandu': 107,
#  'Nepal': 107,
#  'Kabul': 107,
#  'Afghanistan': 107,
#  'Pulaski County': 108,
#  'Polk County': 108,
#  'Lakeland': 108,
#  'Dom DeLuise': 109,
#  'Paul Dooley': 109,
#  'Danny Aiello': 109,
#  'Don Ameche': 109,
#  'Danny DeVito': 109,
#  'William Demarest': 109,
#  'Deion Sanders': 110,
#  'Cris Collinsworth': 110,
#  'Joyce Carol Oates': 111,
#  'Margaret Atwood': 111,
#  'Toni Morrison': 111,
#  'Anne Heche': 112,
#  'Helena Bonham Carter': 112,
#  'Anne Hathaway': 112,
#  'Paul Giamatti': 113,
#  'Paul Dano': 113,
#  'Billy Crudup': 113,
#  'Big Miracle': 114,
#  'The Impossible': 114,
#  'Leslie Dilley': 115,
#  'Darrell Silvera': 115,
#  "Prizzi's Honor": 116,
#  'The Grifters': 116,
#  'Ben Hecht': 117,
#  'William Goldman': 117,
#  'Ernest Lehman': 117,
#  'cardiac arrest': 118,
#  'respiratory failure': 118,
#  'heart failure': 118,
#  'Isaac Stern': 119,
#  'Yo-Yo Ma': 119,
#  'Itzhak Perlman': 119,
#  'Mstislav Rostropovich': 119,
#  'Vladimir Horowitz': 119,
#  'Cinderella': 120,
#  'The Little Mermaid': 120,
#  'Aladdin': 120,
#  'Beauty and the Beast': 120,
#  'Christophe Beck': 121,
#  'Brian Tyler': 121,
#  'Victor Young': 121,
#  'Christopher Young': 121,
#  'cinematographer': 122,
#  'photographer': 122,
#  'photography': 122,
#  'War Horse': 123,
#  'The Water Horse': 123,
#  'Water for Elephants': 123,
#  'Dortmund': 124,
#  'Borussia Dortmund': 124,
#  'Hertha BSC': 124,
#  'Tennis Borussia Berlin': 124,
#  'Bayer 04 Leverkusen': 124,
#  'University of Denver': 125,
#  'DePaul University': 125,
#  'Drake University': 125,
#  'DePauw University': 125,
#  'Butler University': 125,
#  'Valparaiso University': 125,
#  'Bradley University': 125,
#  'United States Forest Service': 126,
#  'United States Fish and Wildlife Service': 126,
#  'National Park Service': 126,
#  'Bureau of Land Management': 126,
#  'Paramaribo': 127,
#  'Georgetown': 127,
#  'Guyana': 127,
#  'Suriname': 127,
#  'electronica': 128,
#  'electro house': 128,
#  'alternative dance': 128,
#  'electronic rock': 128,
#  'electro': 128,
#  'psychedelic trance': 128,
#  'dance-punk': 128,
#  'electronic dance music': 128,
#  'electric folk': 128,
#  'progressive house music': 128,
#  'downtempo': 128,
#  'house music': 128,
#  'folktronica': 128,
#  'intelligent dance music': 128,
#  'techno': 128,
#  'disco': 128,
#  'dance-pop': 128,
#  'dance music': 128,
#  'trip hop': 128,
#  'Italo disco': 128,
#  'electroclash': 128,
#  'Euro disco': 128,
#  'electronic body music': 128,
#  'Hi-NRG': 128,
#  'tech house': 128,
#  'trance': 128,
#  'Eurodance': 128,
#  'Cagney & Lacey': 129,
#  'NYPD Blue': 129,
#  'Homicide: Life on the Street': 129,
#  'Hill Street Blues': 129,
#  'The Producers': 130,
#  'Guys and Dolls': 130,
#  'Thoroughly Modern Millie': 130,
#  'My Fair Lady': 130,
#  'The Music Man': 130,
#  'Burgess Meredith': 131,
#  'Ernest Borgnine': 131,
#  'Manny Coto': 132,
#  'Mark Gordon': 132,
#  'Kim Manners': 132,
#  'Glen Morgan': 132,
#  'Howard Gordon': 132,
#  'Frank Spotnitz': 132,
#  'David Greenwalt': 132,
#  'Javier Grillo-Marxuach': 132,
#  'Tim Minear': 132,
#  'David Fury': 132,
#  'amyotrophic lateral sclerosis': 133,
#  'motor neuron disease': 133,
#  'multiple sclerosis': 133,
#  'novella': 134,
#  'short story': 134,
#  'fiction': 134,
#  'non-fiction': 134,
#  'novel': 134,
#  'Ronny Cox': 135,
#  'Curtis Armstrong': 135,
#  'Kurtwood Smith': 135,
#  'Santana': 136,
#  'Carlos Santana': 136,
#  'Jerry Garcia': 136,
#  'Grateful Dead': 136,
#  'Larry Gelbart': 137,
#  'Jerry Belson': 137,
#  'Richard Brooks': 137,
#  'Albert Brooks': 137,
#  'Melville Shavelson': 137,
#  'Melvin Frank': 137,
#  'Mel Brooks': 137,
#  'James L. Brooks': 137,
#  'Eastern North Carolina': 138,
#  'Buncombe County': 138,
#  'Greensboro': 138,
#  'Asheville': 138,
#  'North Carolina': 138,
#  'Winston-Salem': 138,
#  'Guilford County': 138,
#  'Western North Carolina': 138,
#  'Liechtenstein': 139,
#  'Luxembourg': 139,
#  'Andorra': 139,
#  'Groningen': 140,
#  'North Brabant': 140,
#  'Nijmegen': 140,
#  'Rotterdam': 140,
#  'Utrecht': 140,
#  'Maastricht': 140,
#  'The Hague': 140,
#  'Dordrecht': 140,
#  'Hilversum': 140,
#  'Haarlem': 140,
#  'Amsterdam': 140,
#  'Arnhem': 140,
#  'Breda': 140,
#  'David Kaye': 141,
#  'Kevin Michael Richardson': 141,
#  'Clancy Brown': 141,
#  'Dave Wittenberg': 141,
#  'Keith David': 141,
#  'Cam Clarke': 141,
#  'Michael McConnohie': 141,
#  'Fred Tatasciore': 141,
#  'Aberdeen': 142,
#  'Dunedin': 142,
#  'Edinburgh': 142,
#  'Inverness': 142,
#  'anemia': 143,
#  'anorexia': 143,
#  'Toulouse': 144,
#  'Montpellier': 144,
#  'Lyon': 144,
#  'Metz': 144,
#  'Dijon': 144,
#  'Marseille': 144,
#  'Lille': 144,
#  'University of Georgia': 145,
#  'Morehouse College': 145,
#  'Clark Atlanta University': 145,
#  'Mercer University': 145,
#  'Georgia State University': 145,
#  'Emory University': 145,
#  'Spelman College': 145,
#  'Bradley Whitford': 146,
#  'Richard Schiff': 146,
#  'Tony Goldwyn': 146,
#  'Sam Waterston': 146,
#  'skin cancer': 147,
#  'lung cancer': 147,
#  'Morgan Stanley': 148,
#  'Citigroup': 148,
#  'JPMorgan Chase': 148,
#  'Bank of America': 148,
#  'Goldman Sachs': 148,
#  'Graham Chapman': 149,
#  'Terry Gilliam': 149,
#  'Terry Jones': 149,
#  'Monty Python and the Holy Grail': 149,
#  'Eric Idle': 149,
#  'John Cleese': 149,
#  'Monty Python': 149,
#  'Michael Palin': 149,
#  'Peter Facinelli': 150,
#  'Taylor Lautner': 150,
#  'Kristen Stewart': 150,
#  'Robert Pattinson': 150,
#  'The Hunchback of Notre Dame': 151,
#  'Hercules': 151,
#  'New Line Cinema': 152,
#  'Castle Rock Entertainment': 152,
#  'Morgan Creek Productions': 152,
#  'Pulp Fiction': 153,
#  'From Dusk till Dawn': 153,
#  'Jackie Brown': 153,
#  'Kill Bill Volume 1': 153,
#  'Kill Bill Volume 2': 153,
#  'Grindhouse': 153,
#  'Quentin Tarantino': 153,
#  'Soul Surfer': 154,
#  'The Blind Side': 154,
#  'Fantastic Four: Rise of the Silver Surfer': 155,
#  'Fantastic Four': 155,
#  'The Incredibles': 155,
#  'Dave Brubeck': 156,
#  'David Grisman': 156,
#  'David Sanborn': 156,
#  'Dave Grusin': 156,
#  'Jerry Douglas': 156,
#  'Charlie Daniels': 157,
#  'Waylon Jennings': 157,
#  'Hank Williams Jr.': 157,
#  'Willie Nelson': 157,
#  'Merle Haggard': 157,
#  'Majel Barrett': 158,
#  'Michelle Forbes': 158,
#  'Luzerne County': 159,
#  'Butler County': 159,
#  'New Castle County': 159,
#  'Blair County': 159,
#  'Schuylkill County': 159,
#  'Beaver County': 159,
#  'Bucks County': 159,
#  'Cambria County': 159,
#  'Delaware County': 159,
#  'Lehigh County': 159,
#  'Berks County': 159,
#  'Armstrong County': 159,
#  'Clinton County': 159,
#  'mystery fiction': 160,
#  'detective': 160,
#  'police procedural': 160,
#  'Whodunit': 160,
#  'detective fiction': 160,
#  'crime fiction': 160,
#  'brown': 161,
#  'red': 161,
#  'yellow': 161,
#  'blue': 161,
#  'purple': 161,
#  'green': 161,
#  'Joel David Moore': 162,
#  'Jay Baruchel': 162,
#  'Jonah Hill': 162,
#  'Andrea Martin': 163,
#  'Andrea Romano': 163,
#  'Stephanie Morgenstern': 163,
#  'Loyola University Chicago': 164,
#  'Loyola Law School': 164,
#  'St. Bonaventure University': 164,
#  'Loyola Marymount University': 164,
#  "St. John's University": 164,
#  'Loyola University New Orleans': 164,
#  'Gonzaga University': 164,
#  "Saint Joseph's University": 164,
#  ...}

# %%
with open('./initial_hier.json', 'w') as f:
    json.dump(initial_hier, f, indent=4)

# %%
entity2clusterid = {}

for i, cluster in enumerate(clusters_.values()):
    for entity in cluster:
        entity2clusterid[entity] = i

# %%
from collections import defaultdict

clusterid2count = defaultdict(int)


def label_(d, leaf_keys=None, leaf_values=None):
    if leaf_keys is None:
        leaf_keys = []
    if leaf_values is None:
        leaf_values = []
    for key, value in d.items():
        if isinstance(value, dict):  # If the value is another dictionary, recurse into it
            label_(value, leaf_keys, leaf_values)
        else:  # If the value is not a dictionary, then it's a leaf node
            cluster_id = entity2clusterid[value]
            d[key] = [cluster_id, clusterid2count[cluster_id]]
            clusterid2count[entity2clusterid[value]] += 1
    return d

# %%
hierarchy = label_(initial_hier)

# %%
with open('./initial_hier_numeric.json', 'w') as f:
    json.dump(hierarchy, f, indent=4)

# %%
def refine_1(d, clusters_, leaf_keys=None, leaf_values=None):
    if leaf_keys is None:
        leaf_keys = []
    if leaf_values is None:
        leaf_values = []
    
    keys_to_delete = []  # List to hold keys of items to be deleted
    items_to_update = {}  # Dictionary to hold items to be updated

    for key, value in list(d.items()):  # Convert dict_items to a list to safely iterate
        if isinstance(value, dict):  # If the value is another dictionary, recurse into it
            refine_1(value, clusters_, leaf_keys, leaf_values)
        else:
            if value[1] > 0:
                keys_to_delete.append(key)
            else:
                items_to_update[key] = clusters_[value[0]]

    # Now, delete keys marked for deletion
    for key in keys_to_delete:
        del d[key]

    # Update the dictionary with new values
    for key, new_value in items_to_update.items():
        d[key] = new_value

    return d

# %%
hierarchy = refine_1(hierarchy, clusters_)
with open('./refined_hier.json', 'w') as f:
    json.dump(hierarchy, f, indent=4)

# %%
def refine_2(d):
    # Recursive function to process and refine each dictionary
    def process_dict(sub_dict):
        for key in list(sub_dict.keys()):  # Iterate over a copy of the keys
            value = sub_dict[key]
            if isinstance(value, dict):
                if value:  # Check if the dictionary is not empty
                    result = process_dict(value)
                    # If the result is a single entry with a list, replace the current dict
                    if len(result) == 1 and isinstance(list(result.values())[0], list):
                        sub_dict[key] = list(result.values())[0]
                    else:
                        sub_dict[key] = result
                else:
                    del sub_dict[key]  # Remove empty dictionaries
        return sub_dict

    # Copy the original dictionary to avoid modification issues
    refined_dict = process_dict(d.copy())
    return refined_dict

# %%
hierarchy = refine_2(hierarchy)
with open('./refined_hier.json', 'w') as f:
    json.dump(hierarchy, f, indent=4)

# %%
def refine_3(d):
    # Recursive function to process and refine each dictionary
    def process_dict(sub_dict):
        new_dict = {}  # To accumulate refined results
        for key, value in list(sub_dict.items()):
            if isinstance(value, dict):
                processed = process_dict(value)  # Recursively process
                if processed:  # Only add non-empty results
                    new_dict[key] = processed
            else:  # Keep non-dict items as they are
                new_dict[key] = value
        return new_dict

    # Start the processing with the original dictionary
    refined_dict = process_dict(d)
    return refined_dict

# %%
hierarchy = refine_3(hierarchy)
with open('./refined_hier.json', 'w') as f:
    json.dump(hierarchy, f, indent=4)

# %%
from utils import refine_4
import json

with open('/data/pj20/lamake_data/FB15K-237/seed_clusters.json', 'r') as f:
    seed_clusters = json.load(f)
    
hierarchy = refine_4(seed_clusters)

with open('./refined_hier.json', 'w') as f:
    json.dump(hierarchy, f, indent=4)

# %%
from openai import OpenAI

with open('./openai_api.key', 'r') as f:
    api_key = f.read().strip()
client = OpenAI(api_key=api_key)

def gpt_chat_return_response(model, prompt, seed=44):
    response = client.chat.completions.create(
        model=model,
        messages=[
            {"role": "user", "content": prompt}
        ],
        max_tokens=200,
        temperature=0,
        seed=seed,
        logprobs=True
    )
    return response
